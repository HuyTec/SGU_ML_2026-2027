# %% [markdown]
# # ex2_scientific_1

# %% [markdown]
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt # type: ignore
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: user 2 μs, sys: 1 μs, total: 3 μs
# Wall time: 5.48 μs

# %% [markdown]
# ### Mã kiểm tra dữ liệu

# %%
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.01, 0.98]: 10 samples [[0.92892452 0.25078973 0.66694081 0.06070655 0.37970572 0.10619405
#  0.49258339 0.2904538  0.15606479 0.66313446]]
# + y: len=50, [0.04, 0.99]: 10 samples [[0.95799048 0.90028008 0.84256918 0.21356981 0.91013776 0.17762063
#  0.92078712 0.63974899 0.10597432 0.04376865]]
# + colors: len=50, [0.04, 0.99]: 10 samples [[0.78354692 0.72697414 0.04558425 0.12759989 0.85724337 0.47859715
#  0.32595021 0.52657806 0.04406751 0.95935127]]
# + area: len=50, [0.04, 703.27]: 10 samples [[ 17.25322561 222.58824702  58.41809704  17.09320231 543.25543205
#  166.43803341  33.64967386  63.5788621  550.72357678 629.43440494]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.savefig("ex2_dothi.png")
plt.show()

# %% [markdown]
# ## Kết thúc
