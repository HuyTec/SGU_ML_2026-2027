# %% [markdown]
# # Bài 1.4: Tính toán đơn giản
# • Tạo tập tin ex1_calc.py trong thư mục lession1:

# %% [markdown]
# ## Hướng dẫn
# • Gõ %run ex1_calc.py

# %%
# %run ex1_calc.py
# Out:
# Calculator Basic
# c = 12 + 23 = 35
