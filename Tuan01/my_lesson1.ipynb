# %% [markdown]
# # Bài 1.4: Tính toán đơn giản
# • Tạo tập tin ex1_calc.py trong thư mục lession1:

# %% [markdown]
# ## Hướng dẫn
# • Gõ %run ex1_calc.py

# %% [markdown]
# ## Cách 1: Nhập trực tiếp

# %%
# %run ex1_calc.py
# Out:
# Calculator Basic
# c = 12 + 23 = 35

# %% [markdown]
# ## Cách 2: Nhập thông qua file

# %%
# !python ex1_calc.py < calc.txt
# Out:
# Calculator Basic
# Moi ban nhap so a: Moi ban nhap so b: c = 30 + 20 = 50
