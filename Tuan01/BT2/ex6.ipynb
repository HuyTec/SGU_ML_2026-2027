# %% [markdown]
# # ex6: Kiểm tra số nguyên tố

# %% [markdown]
# ## Nôi dung bài
# Nhập vào một số nguyên dương n. Hãy kiểm tra xem n có phải là nguyên tố không?

# %% [markdown]
# ## Bài làm

# %%
n = int(input("Moi ban nhap so nguyen n: "))

print(f'Ban da nhap: {n}')

if n < 2 : lant = False
elif n % 2 == 0 : lant = False
elif n == 2: lant = True
elif(n > 2):
    lant = True
    for i in range(3, int(n**0.5+1), 2):
        if n % i == 0 : lant = False

if lant == True:
    print(f'{n} la so nguyen to.')
else:
    print(f'{n} khong la so nguyen to.')
# Out:
# Ban da nhap: 5
# 5 la so nguyen to.

# %% [markdown]
# ## Kết thúc
