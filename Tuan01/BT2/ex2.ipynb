# %% [markdown]
# # ex2: Đổi sang giờ phút giây

# %% [markdown]
# ## Nội dung bài
# Một thiết bị hoạt động được t giây. Hãy viết chương trình chuyển số giây đó dưới dạng số giờ, số phút và số giây.

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Nhập dữ liệu

# %%
t = None
# %run ex2_input.py
print("Bạn đã nhập: ", t)
# Out:
# Bạn đã nhập:  4810

# %% [markdown]
# ### Xử lý

# %%
# %time
hh = int(t/3600)
mm = int((t % 3600)/60)
ss = int(t % 60)
# Out:
# CPU times: user 8 μs, sys: 1 μs, total: 9 μs
# Wall time: 16 μs

# %% [markdown]
# ### Xuất dữ liệu

# %%
print(f'{t} giay co dang {hh}:{mm}:{ss}')
# Out:
# 4810 giay co dang 1:20:10

# %% [markdown]
# ## Kết thúc
