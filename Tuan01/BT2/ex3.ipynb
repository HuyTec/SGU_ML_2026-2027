# %% [markdown]
# # ex3: Giải phương trình bậc 1

# %% [markdown]
# ## Nội dung bài
# Nhập 2 số thực a, b. Tìm nghiệm của phương trình bậc 1 : $ax + b = 0$.

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Nhập dữ liệu

# %%
a = None
b = None
# %run ex3_input.py
print('Bạn đã nhập a = %s, b = %s' % (a, b))
# Out:
# Bạn đã nhập a = 1, b = 5

# %% [markdown]
# ### Xử lý

# %%
# %time
flag = 1
if a == 0:
    if b == 0: flag = -1
    else: flag = 0
elif b == 0: x = 0
else :x = -b/a
# Out:
# CPU times: user 4 μs, sys: 0 ns, total: 4 μs
# Wall time: 8.58 μs

# %% [markdown]
# ### Xuất kết quả

# %%
s = f'Phương trình {a}x + {b} = 0'
if flag == -1:
    print(f'{s} vô số nghiệm.')
elif flag == 0:
    print(f'{s} vô nghiệm.')
else:
    print(f'{s} có 1 nghiệm x = {x: .2f}.')
# Out:
# Phương trình 1x + 5 = 0 có 1 nghiệm x = -5.00.

# %% [markdown]
# ## Kết thúc
