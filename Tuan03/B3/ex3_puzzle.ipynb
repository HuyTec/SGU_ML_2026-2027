# %% [markdown]
# # Buổi 4: Tìm kiếm trong không gina trạng thái

# %% [markdown]
# ## Bài 3: Trò chơi 8-Puzzles
# Cho bàn cờ độ rộng 3 x 3 chứa 8 con số từ 1 đến 8 và 1 ô trống xuất hiện ngẫu nhiên. <br>
#
# Hãy xếp thứ tự các con số tăng dần từ 1 đến 8 theo chiều từ trái sang phải và từ trên xuống dưới.<br>
#
# ![image](puzzle.png)

# %% [markdown]
# ## Bài làm:

# %% [markdown]
# **puzzle.inp**
# ```
# 4 8 1       # trạng thái đầu
# 6 3 0
# 2 7 5
# 1 2 3       # trạng thái đích
# 4 5 6
# 7 8 0
# ```

# %% [markdown]
# ### Đọc dữ liệu

# %%
from ex3_puzzle import readfile
import pprint

start, goal = readfile()

pprint.pprint(start)
pprint.pprint(goal)
# Out:
# ((4, 8, 1), (6, 3, 0), (2, 7, 5)), parent: None
# ((1, 2, 3), (4, 5, 6), (7, 8, 0)), parent: None

# %% [markdown]
# ### Hàm tìm vị trí ô trống của trạng thái (tương đương số 0)

# %%
from ex3_puzzle import pos0

k = pos0(start)
h = pos0(goal)

print(k, h)
# Out:
# (1, 2) (2, 2)
